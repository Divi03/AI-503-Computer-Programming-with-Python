# %% [markdown]
# # Experiment 3: String Manipulation, Number System and Conversions
#
# Date: 11/09/2025
#
# ### Objective
# To perform base conversions and string-to-float operations.

# %%
# Decimal to Binary, Octal and Hexadecimal Conversion

decimal_number = int(input("Enter a decimal number: "))

binary = bin(decimal_number)
octal = oct(decimal_number)
hexadecimal = hex(decimal_number)

print("Binary equivalent:", binary)
print("Octal equivalent:", octal)
print("Hexadecimal equivalent:", hexadecimal)

"""
The program takes a decimal integer as input and converts it into binary, 
octal, and hexadecimal formats using Python’s built-in functions bin(), oct(), 
and hex(). This shows Python’s support for number system conversions.

"""
# Out:
# Enter a decimal number:  20
# Binary equivalent: 0b10100
# Octal equivalent: 0o24
# Hexadecimal equivalent: 0x14

# %%
# String to float conversion and addition

num_str = input("Enter a floating-point number as a string: ")

num_float = float(num_str)
result = num_float + 10.5

print("Result after adding 10.5:", result)

"""
A numeric value is accepted as a string and converted into a floating-point number
using float(). A constant value is added, and the result is printed. This demonstrates
type conversion and arithmetic operations on floating-point numbers.

"""
# Out:
# Enter a floating-point number as a string:  12.5
# Result after adding 10.5: 23.0
