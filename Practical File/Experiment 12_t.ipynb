# %% [markdown]
# # Experiment 12: Operator Overloading and Error Handling
# Date: 20/11/2025

# %%
# Operator overloading using + for Student class

class Student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks

    def __add__(self, other):
        return self.marks + other.marks


# Creating student objects
s1 = Student("Alice", 85)
s2 = Student("Bob", 90)

total_marks = s1 + s2

print("Total Marks of both students:", total_marks)

"""
Overloads the + operator to add marks of two student objects.
"""
# Out:
# Total Marks of both students: 175

# %%
# Voting eligibility validation

try:
    name = input("Enter your name: ")
    age = int(input("Enter your age: "))

    if age >= 18:
        print(name, "is eligible to vote.")
    else:
        print(name, "is not eligible to vote.")
except ValueError:
    print("Invalid age input. Please enter a valid integer age.")

"""
Checks user input to determine voting eligibility based on age.
"""
# Out:
# Enter your name:  Max
# Enter your age:  23
# Max is eligible to vote.

# %%
# Repeated integer input with exception handling

while True:
    try:
        num = int(input("Enter an integer: "))
        print("You entered:", num)
        break
    except ValueError:
        print("Invalid input, please enter an integer.")

"""
Handles invalid input using try-except and repeatedly asks until a valid integer is entered.
"""
# Out:
# Enter an integer:  123
# You entered: 123
