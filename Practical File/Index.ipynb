# %% [markdown]
# # Python Programming Lab - Practical Record

# %% [markdown]
# ### Name    : Divyansh Sehgal
# ### Roll No. : 25901327
# ### Institution NIT Jalandhar
# ### Department Centre for Artificial Intelligence
#
# Repository: [GitHub](http://github.com/Divi03/AI-503-Computer-Programming-with-Python)

# %% [markdown]
# | **Experiment No.** | **Experiment Name**                                                                                               | **Date** |
# | ------------------ | ----------------------------------------------------------------------------------------------------------------- | ------------------ |
# | 1                  | Installation and Basic Programs (Variables and Data Types, Arithmetic, Comparison, Assignment, Logical Operators) | **28/08/2025**     |
# | 2                  | Operators Based Programs                                                                                          | **04/09/2025**     |
# | 3                  | String Manipulation, Number System and Conversions                                                                | **11/09/2025**     |
# | 4                  | Operator Precedence, Conditional Statements, Loops (For and While)                                                | **18/09/2025**     |
# | 5                  | Nested Loops, Keyword Arguments                                                                                   | **25/09/2025**     |
# | 6                  | Programs Based on Functions                                                                                       | **26/09/2025**     |
# | 7                  | Modules and Packages                                                                                              | **30/09/2025**     |
# | 8                  | String and Its Operations                                                                                         | **16/10/2025**     |
# | 9                  | File Handling                                                                                                     | **30/10/2025**     |
# | 10                 | Data Structures: Lists, Tuples, Sets                                                                              | **06/11/2025**     |
# | 11                 | Programming Exercises with Classes and Objects, Inheritance                                                       | **13/11/2025**     |
# | 12                 | Operator Overloading and Error Handling                                                                           | **20/11/2025**     |
